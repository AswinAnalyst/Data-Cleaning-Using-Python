# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\aswin\OneDrive\Desktop\Pandas\Customer Call List.xlsx",index_col='CustomerID')
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df= df.drop_duplicates()
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df =df.drop(columns='Not_Useful_Column')
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df['Last_Name'].str.strip()
# Out:
# CustomerID
# 1001        Baggins
# 1002          Nadir
# 1003         /White
# 1004        Schrute
# 1005           Snow
# 1006        Swanson
# 1007         Winger
# 1008         Holmes
# 1009            NaN
# 1010         Parker
# 1011         Gamgee
# 1012      ...Potter
# 1013         Draper
# 1014          Knope
# 1015    Flenderson_
# 1016        Weasley
# 1017          Scott
# 1018           Kent
# 1019         Braton
# 1020      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'] = df['Last_Name'].str.lstrip("/")
df['Last_Name'] = df['Last_Name'].str.lstrip("...")
df['Last_Name'] = df['Last_Name'].str.rstrip("_")
df['Last_Name'] = df['Last_Name'].str.strip("123._/")

# %%
df['Last_Name']
# Out:
# CustomerID
# 1001       Baggins
# 1002         Nadir
# 1003         White
# 1004       Schrute
# 1005          Snow
# 1006       Swanson
# 1007        Winger
# 1008        Holmes
# 1009           NaN
# 1010        Parker
# 1011        Gamgee
# 1012        Potter
# 1013        Draper
# 1014         Knope
# 1015    Flenderson
# 1016       Weasley
# 1017         Scott
# 1018          Kent
# 1019        Braton
# 1020     Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter       White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           N/a
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
## Lets Jump to the phone number column.

# %%
df['Phone_Number']= df['Phone_Number'].str.replace('[^a-zA-Z0-9]','',regex = True)
df['Phone_Number']
# regex is a special pattern used to match or search for certain characters in a string

df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' +x[3:6] + '-' + x[6:10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 5
#       2 df['Phone_Number']
#       3 # regex is a special pattern used to match or search for certain characters in a string
# ----> 5 df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' +x[3:6] + '-' + x[6:10])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
# ...

# %%
'''
Why this error comes means in pandas missing values(NaN) are actually stored as float type,
even the rest of the columns looks like strings.We can't do slicing on float values.
So we want to convert that into the strings.
'''
# Out:
# "\nWhy this error comes means in pandas missing values(NaN) are actually stored as float type,\neven the rest of the columns looks like strings.We can't do slicing on float values.\nSo we want to convert that into the strings.\n"

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White         nan--
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger         nan--
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN          Na--
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee         nan--
# 1012            Harry      Potter         nan--
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent         nan--
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('nan--','')
df['Phone_Number'] = df['Phone_Number'].str.replace('Na--','')

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1019            Creed      Braton
# 1020           Anakin   Skywalker  876-678-3469
#
# ...

# %%
'''
Next we jump to the address column.If the people who are on the call center want all these seperated
into three diffent column they can easily read it see what the zip code is where they live like whatever they want.
'''

# %%
df[["Street address","state","Zip code"]] = df['Address'].str.split(',',n=2,expand=True)
# using expand true each part after splitting becomes a seperate column.
# expand=False(default)- returns a series of lists.

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1019            Creed      Braton
# 1020           Anakin   Skywalker  876-678-3469
#
# ...

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1019            Creed      Braton
# 1020           Anakin   Skywalker  876-678-3469
#
# ...

# %%
df.str.replace('N/a','')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43080\156777783.py in ?()
# ----> 1 df.str.replace('N/a','')
#       2 df
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
'''
when you are using .str directly on the entire directly on the entire DataFrame(df),and .str
only works on a single column(a series),not on the whole column.
'''

# %%
df = df.replace('N/a','')
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1019            Creed      Braton
# 1020           Anakin   Skywalker  876-678-3469
#
# ...

# %%
df = df.fillna('')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1019            Creed      Braton
# 1020           Anakin   Skywalker  876-678-3469
#
# ...

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact'] == 'Yes':
        df.drop(x,inplace=True)

df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1003           Walter       White
# 1005              Jon        Snow  876-678-3469
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1020           Anakin   Skywalker  876-678-3469
#
#                                    Address Paying Customer Do_Not_Contact  \
# CustomerID
# 1001                 123 Shire Lane, Shire               Y             No
# ...

# %%
'''
Step1- This loops through all the row index in your dataframe.
ex: If your df has 5 rows this will loop through x=0,1,2.

Step2- For each row, it checks the values in the Do_Not_Contact column.
df.loc[x,'Do_Not_Contact'] means:
.look at row x
.in column Do_Not_Contact.
.if the value is yes the row will be remove.

inplace=True the change is made directly in the original DataFrame.It does not return a new dataframe.

# %%
for x in df.index:
    if df.loc[x,'Phone_Number'] == '':
        df.drop(x,inplace=True)
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1005              Jon        Snow  876-678-3469
# 1008         Sherlock      Holmes  876-678-3469
# 1010            Peter      Parker  123-545-5421
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1020           Anakin   Skywalker  876-678-3469
#
#                                    Address Paying Customer Do_Not_Contact  \
# CustomerID
# 1001                 123 Shire Lane, Shire               Y             No
# 1005                      123 Dragons Road               Y             No
# 1008                         98 Clue Drive               N             No
# 1010            25th Main Street, New York               Y             No
# ...
